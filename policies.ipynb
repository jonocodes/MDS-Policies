# %%
import policies

policies.active_policies
# Out:
#                                 policy_id  \
# 0    66ccd4c5-e6ee-4a07-8869-c1a3efa69061
# 1    37dd3675-548b-46a9-8f8f-d74de0edb6c6
# 2    9a157d1a-b2b9-418e-8586-eba0ba38b8b6
# 3    85de4fd1-8b43-4509-b73e-ec97c1530dab
# 4    67991894-1079-4ef9-9be2-7e32a6fcafe2
# ..                                    ...
# 427  2d410e57-bbdb-4b8a-9dce-07869fa8c690
# 428  2f2ee7a8-f1e1-4ab8-8251-5163ce416d0a
# 430  1d409b50-7069-4746-9611-7813b11fc473
# 431  f2048b5f-8505-4cb8-8b38-23dcb2a2c88d
# 432  2be2ce07-26fd-48b5-8e68-527f371531cd
#
#                                          prev_policies  published_date  \
# 0                                                   []   1678893048363
# 1    [83ac04fa-523e-473f-b682-b664a564fd35, efb5856...   1667843479616
# 2    [aec13c88-7ab9-4c6b-8d02-318253ebd475, b822973...   1649433230441
# 3                                                   []   1656451155839
# 4                                                   []   1676069048449
# ...

# %%
policies.rules
# Out:
#                     name  maximum  minimum  \
# 0           Distribution      3.0      NaN
# 1           Distribution      3.0      NaN
# 2           Distribution      3.0      NaN
# 3           Distribution      3.0      NaN
# 4           Distribution      3.0      NaN
# ...                  ...      ...      ...
# 1872        Distribution      8.0      NaN
# 1873         Vehicle Cap   1000.0      NaN
# 1874  Parking Time Limit      5.0      0.0
# 1875  Operator Drop-offs      NaN      8.0
# 1876          No Parking      0.0      0.0
#
#                                    rule_id messages rule_type rule_units  \
# 0     b3d330df-edf4-64dd-05bd-6c8275455e95       {}     count    devices
# 1     e9aaaa20-5389-3cfd-3c41-fbe9528b9d62       {}     count    devices
# 2     c37c4cf3-bbcc-121e-09f7-fde8560ee6d9       {}     count    devices
# 3     5fdcb862-dc51-8aae-8ff9-50ceacc1c19c       {}     count    devices
# 4     367a88ce-333b-6416-5b81-5a10e23a4b44       {}     count    devices
# ...

# %%
policies.type_counts
# Out:
#              total
# rule_type
# count         1694
# time           138
# rate            22
# speed           14
# utilization      2

# %%
pol.type_counts.sort_values(by='total', ascending=1).plot.barh(ylabel='rule')
# Out:
# <AxesSubplot: ylabel='rule'>
