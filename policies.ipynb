# %%
import policies

# %% [markdown]
# # All region policies

# %%
policies.print_stats()
# Out:
# fetching data from API for region ALL
# total policies in region = 433
# active policies last month (2023/02/01 - 2023/02/28) = 362
# unique rules in active policies = 1870
#
# specified vehicle representation in rules =
# scooter 495
# bicycle  84
#   moped   1
#   other   2
#
# rule types =
# count          1694
# time            138
# rate             22
# speed            14
# utilization       2

# %% [markdown]
# # Oakland policies

# %%
policies.print_stats('oakland')
# Out:
# fetching data from API for region oakland
# total policies in region = 5
# active policies last month (2023/02/01 - 2023/02/28) = 5
# unique rules in active policies = 4
#
# specified vehicle representation in rules =
# scooter 4
#
# rule types =
# count    2
# time     2
